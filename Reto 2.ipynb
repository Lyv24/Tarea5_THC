# %% [markdown]
# <a href="https://colab.research.google.com/github/Lyv24/Tarea5_THC/blob/main/Reto%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reto 2. Convertidor de unidades \\
# Cruz Contreras Isari Lyvier

# %%
#Programa para convertir unidades de longitud, masa y tiempo entre el Sistema Internacional de Unidades y el Sistema Inglés
x=input("¿Qué tipo de unidades quiere convertir?(Escribe: longitud, volumen, masa, tiempo o salir del programa) ")
if x == "salir del programa":
  print("Usted ha salido del programa")
elif x == "longitud":
  y=input("Convertir del sistema______al sistema______(Escribir: SI a Sistema Inglés o Sistema Inglés a SI) ")
  if y == "SI a Sistema Inglés":
    h=input("Unidades que ingresará (Escriba: cm, m ó km) ")
    k=float(input("Escriba la cantidad "))
    o=input("Unidades a las que se desea convertir (Escriba: mi, yd ó ft) ")
    if h == "cm":
      if o == "mi":
        print(k/160900, " mi")
      elif o == "yd":
        print(k/91.44, " yd")
      elif o == "ft":
        print(k/30.48, " ft")
    if h == "m":
      if o == "mi":
        print(k/1609, " mi")
      elif o == "yd":
        print(k*1.094, " yd")
      elif o == "ft":
        print(k*3.281, " ft")
    if h == "km":
      if o == "mi":
        print(k/1.609, " mi")
      elif o == "yd":
        print(k*1094, " yd")
      elif o == "ft":
        print(k*3281, " ft")
  elif y == "Sistema Inglés a SI":
    h=input("Unidades que ingresará (Escriba: mi, yd ó ft) ")
    k=float(input("Escriba la cantidad "))
    o=input("Unidades a las que se desea convertir (Escriba: cm, m ó km) ")
    if h == "mi":
      if o == "cm":
        print(k*160900, " cm")
      elif o == "m":
        print(k*1609, " m")
      elif o == "km":
        print(k*1.609, " km")
    if h == "yd":
      if o == "cm":
        print(k*91.44, " cm")
      elif o == "m":
        print(k/1.094, " m")
      elif o == "km":
        print(k/1094, " km")
    if h == "ft":
      if o == "cm":
        print(k*30.48, " cm")
      elif o == "m":
        print(k/3.281, " m")
      elif o == "km":
        print(k/3281, " km")
elif x == "masa":
  y=input("Convertir del sistema______al sistema______(Escribir: SI a Sistema Inglés o Sistema Inglés a SI) ")
  if y == "SI a Sistema Inglés":
    h=input("Unidades que ingresará (Escriba: kilogramos ó gramos) ")
    k=float(input("Escriba la cantidad "))
    o=input("Unidades a las que se desea convertir (Escriba: onzas ó libras) ")
    if h == "kilogramos":
      if o == "onzas":
        print(k*35.274, " onzas")
      elif o == "libras":
        print(k*2.205, " libras")
    if h == "gramos":
      if o == "onzas":
        print(k/28.35, " onzas")
      elif o == "libras":
        print(k/453.6, " libras")
  elif y == "Sistema Inglés a SI":
    h=input("Unidades que ingresará (Escriba: onzas ó libras) ")
    k=float(input("Escriba la cantidad "))
    o=input("Unidades a las que se desea convertir (Escriba: kilogramos ó gramos) ")
    if h == "onzas":
      if o == "kilogramos":
        print(k/35.274, " kilogramos")
      elif o == "gramos":
        print(k*28.35, " gramos")
    if h == "libras":
      if o == "kilogramos":
        print(k/2.205, " kilogramos")
      elif o == "gramos":
        print(k*453.6, " gramos")

elif x == "tiempo":
  y=input("Unidades que ingresará (Escriba: días, horas, minutos, segundos, milisegundos) ")
  k=float(input("Escriba la cantidad "))
  o=input("Unidades a las que se desea convertir (Escriba: días, horas, minutos, segundos, milisegundos) ")
  if y == "días":
    if o == "días":
      print(k, "días")
    elif o == "horas":
      print(k*24, "horas")
    elif o == "minutos":
      print(k*1440, "minutos")
    elif o == "segundos":
      print(k*86400, "segundos")
    elif o == "milisegundos":
      print(k*86400000, "milisegundos")
  if y == "horas":
    if o == "horas":
      print(k, "horas")
    elif o == "días":
      print(k/24, "días")
    elif o == "minutos":
      print(k*60, "minutos")
    elif o == "segundos":
      print(k*3600, "segundos")
    elif o == "milisegundos":
      print(k*3600000, "milisegundos")
  if y == "minutos":
    if o == "minutos":
      print(k, "minutos")
    elif o == "días":
      print(k/1440, "días")
    elif o == "horas":
      print(k/60, "horas")
    elif o == "segundos":
      print(k*60, "segundos")
    elif o == "milisegundos":
      print(k*60000, "milisegundos")
  if y == "segundos":
    if o == "segundos":
      print(k, "segundos")
    elif o == "días":
      print(k/86400, "días")
    elif o == "horas":
      print(k/3600, "horas")
    elif o == "minutos":
      print(k/60, "minutos")
    elif o == "milisegundos":
      print(k*1000, "milisegundos")
  if y == "milisegundos":
    if o == "milisegundos":
      print(k, "milisegundos")
    elif o == "días":
      print(k/86400000, "días")
    elif o == "horas":
      print(k/3600000, "horas")
    elif o == "minutos":
      print(k/60000, "minutos")
    elif o == "segundos":
      print(k/1000, "segundos")
elif x == "volumen":
  y=input("Convertir del sistema______al sistema______(Escribir: SI a Sistema Inglés o Sistema Inglés a SI)")
  if y == "SI a Sistema Inglés":
    y=input("Unidades que ingresará (Escriba: litro) ")
    k=float(input("Escriba la cantidad "))
    o=input("Unidades a las que se desea convertir (Escriba: galón) ")
    if y == "litro"  :
      print(k/3.785, "litros")
  if y == "Sistema Inglés a SI":
    y=input("Unidades que ingresará (Escriba: galón) ")
    k=float(input("Escriba la cantidad "))
    o=input("Unidades a las que se desea convertir (Escriba: litro) ")
    if y == "galón"  :
      print(k*3.785, "galones")
else:
  print("Lo siento, no reconozco esas unidades")
# Out:
# ¿Qué tipo de unidades quiere convertir?(Escribe: longitud, volumen, masa, tiempo o salir del programa) salir del programa
# Usted ha salido del programa
